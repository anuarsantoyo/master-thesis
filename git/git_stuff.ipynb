# %% [markdown]
# # Setup
# This steps should be made only once

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Github/master_thesis/
# Out:
# /content/drive/MyDrive/Github/master_thesis

# %%
#!git clone https://github.com/anuarsantoyo/master-thesis.git

# %% [markdown]
# # Git Tools
# Set of tools to easily work with GitHub
# repository

# %% [markdown]
# ## Pull, Add, Commit and Push

# %% [markdown]
# !git config --global user.email "anuarsantoyo@hotmail.com" # Email
# !git config --global user.name "Anuar" #Name

# %%
# !git config --global user.email "anuarsantoyo@hotmail.com" # Email
# !git config --global user.name "Anuar" #Name
# !git pull
# Out:
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 14 (delta 7), reused 14 (delta 7), pack-reused 0
# Unpacking objects: 100% (14/14), done.
# From https://github.com/anuarsantoyo/master-thesis
#    f6802f0..1930114  master     -> origin/master
# Updating f6802f0..1930114
# Fast-forward
#  clustering/anuar_test.ipynb              |   4881 +-
#  data/220129_preprocessed_data.csv        | 125302 ++++++++++++++++++++++++++++
#  data/coronavirus-data-explorer.png       |    Bin 0 -> 436207 bytes
#  preprocessing/220125_preprocessing.ipynb |    688 +-
#  4 files changed, 129134 insertions(+), 1737 deletions(-)
#  create mode 100644 data/220129_preprocessed_data.csv
#  create mode 100644 data/coronavirus-data-explorer.png

# %%
# !git pull
# !git add . # '.' Adds all changes, if you wanto to only add specific files wirte file name instead of '.'
# !git commit -m "Updated rest of categorical values and finished first nan handling"
# !git push -u origin master #Must be your branch name

# %% [markdown]
# ## Merge to master

# %%
# !git merge master
# !git checkout master
# !git merge <yourbranch>

# %% [markdown]
# ## Create new branch

# %%
# !git checkout -b anuar
