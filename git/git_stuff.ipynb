# %% [markdown]
# # Setup
# This steps should be made only once

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Github/master_thesis/
# Out:
# /content/drive/MyDrive/Github/master_thesis

# %%
#!git clone https://github.com/anuarsantoyo/master-thesis.git

# %% [markdown]
# # Git Tools
# Set of tools to easily work with GitHub
# repository

# %% [markdown]
# ## Pull, Add, Commit and Push

# %% [markdown]
# !git config --global user.email "anuarsantoyo@hotmail.com" # Email
# !git config --global user.name "Anuar" #Name

# %%
# !git config --global user.email "anuarsantoyo@hotmail.com" # Email
# !git config --global user.name "Anuar" #Name
# !git pull
# Out:
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 83 (delta 11), reused 78 (delta 6), pack-reused 0
# Unpacking objects: 100% (83/83), done.
# From https://github.com/anuarsantoyo/master-thesis
#    9d7c164..4a8f1f8  master     -> origin/master
# Updating 9d7c164..4a8f1f8
# Checking out files: 100% (64/64), done.
# Fast-forward
#  clustering/220201_behaviour_clustering.ipynb       |  6354 +++
#  data/observations_30012022.csv                     |   705 +
#  .../.DS_Store                                      |   Bin 0 -> 6148 bytes
#  .../01_indlagte_pr_vaccinationsstatus.csv          |     4 +
#  ...tede_tilf\303\246lde_pr_vaccinationsstatus.csv" |     4 +
#  ...vacc_status_pr_aldersgrp_de_seneste_7_dage.csv" |    19 +
#  ..._pr_vaccinationsstatus_pr_aldersgrp_pr_uge.csv" |  1045 +
#  ...ationsstatus_pr_aldersgrp_de_seneste_7_dage.csv |    19 +
#  ...e_pr_vaccinationsstatus_pr_aldersgrp_pr_uge.csv |   985 +
#  .../Gennembruds_DB/0_read_me_gennembruds_db.txt    |   125 +
#  .../Kommunalt_DB/01_noegletal.csv                  |     2 +
#  .../02_indlaeggelser_pr_dag_kummulativt.csv        |   705 +
#  .../03_indl\303\246ggelser_pr_aldersgrp.csv"       |    12 +
#  .../04_bekraeftede_tilfaelde_doed_pr_aldersgrp.csv |    12 +
#  .../Kommunalt_DB/05_nye_indlaeggelser_pr_dag.csv   |   705 +
#  .../Kommunalt_DB/06_doed_pr_dag_kumuleret.csv      |   706 +
#  .../07_bekraeftede_tilfaelde_pr_dag_pr_kommune.csv | 49661 +++++++++++++++++++
#  .../Kommunalt_DB/08_proever_pr_uge_pr_region.csv   |   105 +
#  .../09_tilfaelde_aldersgrp_kommuner.csv            |  1016 +
#  .../Kommunalt_DB/0_read_me_kommunalt_db.txt        |   264 +
#  .../Kommunalt_DB/10_Kommune_kort.csv               |   100 +
#  .../Kommunalt_DB/11_kort_pr_kommune.csv            |   100 +
#  .../12_pcr_og_antigen_test_pr_kommune.csv          | 16345 ++++++
#  .../13_mistaenkte_pos_pr_kommune_pr_dag.csv        |  8954 ++++
#  .../14_tilfaelde_aldersgrp_kommuner_7dage.csv      |   993 +
#  .../15_indl\303\246ggelser_pr_fnkt_alder.csv"      |    11 +
#  .../16_bekraeftede_tilfaelde_fnkt_alder.csv        |    11 +
#  .../17_tilfaelde_fnkt_alder_kommuner.csv           |   912 +
#  .../18_tilfaelde_fnkt_alder_kommuner_7dage.csv     |   898 +
#  .../Regionalt_DB/01_noegle_tal.csv                 |    14 +
#  .../Regionalt_DB/02_hospitalsbelaegning.csv        |     6 +
#  ...ede_tilfaelde_doede_indlagte_pr_dag_pr_koen.csv |  6699 +++
#  .../04_indlagte_pr_alders_grp_pr_region.csv        |    62 +
#  ...ede_tilfaelde_doede_pr_region_pr_alders_grp.csv |    62 +
#  .../06_nye_indlaeggelser_pr_region_pr_dag.csv      |  2932 ++
#  .../07_antal_doede_pr_dag_pr_region.csv            |  1677 +
#  .../08_bekraeftede_tilfaelde_pr_dag_pr_regions.csv |  3415 ++
#  ...bekraeftede_tilfaelde_pr_test_region_pr_uge.csv |   102 +
#  .../Regionalt_DB/0_read_me_regionalt_db.txt        |   404 +
#  ...e_pr_samfundsspor_opgjort_paa_bopaelsregion.csv |    97 +
#  .../11_noegletal_pr_region_pr_aldersgruppe.csv     |    62 +
#  ...pr_region_pr_aldersgruppe_de_seneste_7_dage.csv |    60 +
#  .../Regionalt_DB/13_regionale_kort.csv             |     6 +
#  .../14_testede_pr_test_region_pr_uge.csv           |   105 +
#  .../Regionalt_DB/15_indlagte_pr_region_pr_dag.csv  |  3352 ++
#  .../16_pcr_og_antigen_test_pr_region.csv           |  1009 +
#  .../17_koen_uge_testede_positive_nyindlagte.csv    |   207 +
#  ..._fnkt_alder_uge_testede_positive_nyindlagte.csv |   923 +
#  .../19_indlagte_pr_fnkt_alder_pr_region.csv        |    56 +
#  ...kraeftede_tilfaelde_pr_region_pr_fnkt_alder.csv |    56 +
#  .../21_noegletal_pr_region_pr_fnkt_alder.csv       |    56 +
#  ...l_pr_region_pr_fnkt_alder_de_seneste_7_dage.csv |    55 +
#  .../Regionalt_DB/23_reinfektioner_uge_region.csv   |   358 +
#  .../24_reinfektioner_daglig_region.csv             |  3951 ++
#  ...iv_procent_pr_test_center_de_seneste_7_dage.csv |    99 +
#  ...tigen_test_pr_test_center_de_seneste_7_dage.csv |   212 +
#  ...04_turist_positiv_procent_de_seneste_7_dage.csv |     2 +
#  ...test_center_pr_alders_grp_de_seneste_7_dage.csv |   958 +
#  ...t_center_pr_alders_gruppe_de_seneste_7_dage.csv |  1572 +
#  ...test_center_pr_fnkt_alder_de_seneste_7_dage.csv |   882 +
#  ...test_center_pr_fnkt_alder_de_seneste_7_dage.csv |  1281 +
#  .../Testcenter_DB/0_read_me_test_center_db.txt     |   122 +
#  preprocessing/010222_get_observations.ipynb        |     1 +
#  preprocessing/220201_preprocessing.ipynb           |  7924 +++
#  64 files changed, 129551 insertions(+)
#  create mode 100644 clustering/220201_behaviour_clustering.ipynb
#  create mode 100644 data/observations_30012022.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/.DS_Store
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/01_indlagte_pr_vaccinationsstatus.csv
#  create mode 100644 "data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/02_bekr\303\246ftede_tilf\303\246lde_pr_vaccinationsstatus.csv"
#  create mode 100644 "data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/03_bekr\303\246ftede_tilf\303\246lde_pr_vacc_status_pr_aldersgrp_de_seneste_7_dage.csv"
#  create mode 100644 "data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/04_bekr\303\246ftede_tilf\303\246lde_pr_vaccinationsstatus_pr_aldersgrp_pr_uge.csv"
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/05_nyindlagte_pr_vaccinationsstatus_pr_aldersgrp_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/06_nyindlagte_pr_vaccinationsstatus_pr_aldersgrp_pr_uge.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Gennembruds_DB/0_read_me_gennembruds_db.txt
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/01_noegletal.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/02_indlaeggelser_pr_dag_kummulativt.csv
#  create mode 100644 "data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/03_indl\303\246ggelser_pr_aldersgrp.csv"
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/04_bekraeftede_tilfaelde_doed_pr_aldersgrp.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/05_nye_indlaeggelser_pr_dag.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/06_doed_pr_dag_kumuleret.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/07_bekraeftede_tilfaelde_pr_dag_pr_kommune.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/08_proever_pr_uge_pr_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/09_tilfaelde_aldersgrp_kommuner.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/0_read_me_kommunalt_db.txt
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/10_Kommune_kort.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/11_kort_pr_kommune.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/12_pcr_og_antigen_test_pr_kommune.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/13_mistaenkte_pos_pr_kommune_pr_dag.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/14_tilfaelde_aldersgrp_kommuner_7dage.csv
#  create mode 100644 "data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/15_indl\303\246ggelser_pr_fnkt_alder.csv"
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/16_bekraeftede_tilfaelde_fnkt_alder.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/17_tilfaelde_fnkt_alder_kommuner.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Kommunalt_DB/18_tilfaelde_fnkt_alder_kommuner_7dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/01_noegle_tal.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/02_hospitalsbelaegning.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/03_bekraeftede_tilfaelde_doede_indlagte_pr_dag_pr_koen.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/04_indlagte_pr_alders_grp_pr_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/05_bekraeftede_tilfaelde_doede_pr_region_pr_alders_grp.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/06_nye_indlaeggelser_pr_region_pr_dag.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/07_antal_doede_pr_dag_pr_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/08_bekraeftede_tilfaelde_pr_dag_pr_regions.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/09_bekraeftede_tilfaelde_pr_test_region_pr_uge.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/0_read_me_regionalt_db.txt
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/10_testede_pr_uge_pr_samfundsspor_opgjort_paa_bopaelsregion.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/11_noegletal_pr_region_pr_aldersgruppe.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/12_noegletal_pr_region_pr_aldersgruppe_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/13_regionale_kort.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/14_testede_pr_test_region_pr_uge.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/15_indlagte_pr_region_pr_dag.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/16_pcr_og_antigen_test_pr_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/17_koen_uge_testede_positive_nyindlagte.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/18_fnkt_alder_uge_testede_positive_nyindlagte.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/19_indlagte_pr_fnkt_alder_pr_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/20_bekraeftede_tilfaelde_pr_region_pr_fnkt_alder.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/21_noegletal_pr_region_pr_fnkt_alder.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/22_noegletal_pr_region_pr_fnkt_alder_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/23_reinfektioner_uge_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Regionalt_DB/24_reinfektioner_daglig_region.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/01_pcr_positiv_procent_pr_test_center_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/02_antigen_test_pr_test_center_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/04_turist_positiv_procent_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/05_pcr_testede_personer_pr_test_center_pr_alders_grp_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/06_ag_testede_personer_pr_test_center_pr_alders_gruppe_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/07_pcr_testede_personer_pr_test_center_pr_fnkt_alder_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/08_ag_testede_personer_pr_test_center_pr_fnkt_alder_de_seneste_7_dage.csv
#  create mode 100644 data/raw/observations/overvaagningsdata-dashboard-covid19-31012022-40ip/Testcenter_DB/0_read_me_test_center_db.txt
#  create mode 100644 preprocessing/010222_get_observations.ipynb
#  create mode 100644 preprocessing/220201_preprocessing.ipynb

# %%
#!git pull
# !git add . # '.' Adds all changes, if you wanto to only add specific files wirte file name instead of '.'
# !git commit -m ""
# !git push -u origin master #Must be your branch name
# Out:
# [master 9d7c164] box-plots behaviour cluster
#  1 file changed, 1 insertion(+), 2470 deletions(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 3.62 MiB | 1.95 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/anuarsantoyo/master-thesis.git
#    c35d90e..9d7c164  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
#Force pull
# !git fetch --all
# !git reset --hard origin/master
# Out:
# Fetching origin
# HEAD is now at 73a22ca git conflict solution

# %% [markdown]
# ## Merge to master

# %%
# !git merge master
# !git checkout master
# !git merge <yourbranch>

# %% [markdown]
# ## Create new branch

# %%
# !git checkout -b anuar
