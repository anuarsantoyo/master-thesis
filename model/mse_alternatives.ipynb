# %%
from scipy.stats import poisson
from scipy.stats import nbinom
import matplotlib.pyplot as plt
import numpy as np

# %%
val = []
for i in range(10):
    val.append(nbinom.pmf(i, 8, 0.5))

plt.plot(val)
plt.show()
