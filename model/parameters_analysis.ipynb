# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/modeling/experiments_estimated_parameters.csv', index_col=0)

# %%
for col in df.columns:
    sns.displot(data=df, x=col)
    plt.show()

# %%
df.describe()
# Out:
#               R0      sigma        phi      alpha
# count  40.000000  40.000000  40.000000  40.000000
# mean    1.571600   0.073075  24.769347   0.023388
# std     0.153347   0.036401   0.226276   0.012662
# min     1.453034   0.027902  24.211750   0.003431
# 25%     1.477082   0.032349  24.637022   0.010001
# 50%     1.500000   0.090955  24.726396   0.028000
# 75%     1.610342   0.098422  24.974582   0.029361
# max     2.045553   0.189855  25.000000   0.049860
