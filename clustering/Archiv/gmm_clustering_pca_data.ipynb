# %%
from sklearn.mixture import GaussianMixture
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd 'drive/MyDrive/GitHub/master-thesis'
# Out:
# /content/drive/MyDrive/GitHub/master-thesis

# %%
from clustering.utils import *

# %%
#%cd ..
# Out:
# /content/drive/My Drive/GitHub/master-thesis

# %% [markdown]
# # Import Data

# %%
df, answers, info_dict = get_cluster_input_data(pca_data=True)

# %%
df.head()
# Out:
#        PC_0      PC_1      PC_2      PC_3      PC_4      PC_5      PC_6  \
# 0 -0.699479 -0.770944 -0.628573 -1.347859 -0.362089  1.003139 -0.011299
# 1 -1.042685  0.134720 -0.322130  1.520663 -1.429726  0.553071 -1.170322
# 2 -1.090649  0.528105  0.389838  1.141938  1.297194 -1.068319 -0.257879
# 3  0.103301 -1.561799  1.319970 -0.147182  2.345984  1.095251  0.345532
# 4  1.908322 -1.268602  4.034475 -0.402159  0.807604 -0.425695 -1.042586
#
#        PC_7      PC_8      PC_9  ...  Q14_ocupation_employee_private  \
# 0  0.133365  1.154861 -0.111807  ...                               0
# 1 -1.384575 -1.049615  0.161217  ...                               0
# 2 -0.794440 -0.420931  1.823400  ...                               0
# 3 -2.371791 -1.517903 -0.073005  ...                               0
# 4 -1.173911  0.550262  1.374492  ...                               0
#
#    Q14_ocupation_unemployed Q14_ocupation_employee_public  \
# 0                         0                             1
# 1                         0                             1
# 2                         0                             1
# 3                         0                             0
# 4                         0                             0
#
#    Q14_ocupation_self_employed Q14_ocupation_student  Q14_ocupation_other  \
# 0                            0                     0                    0
# 1                            0                     0                    0
# 2                            0                     0                    0
# 3                            0                     0                    0
# 4                            0                     0                    1
#
#    Q15_economic_spectrum  Q15_social_spectrum  Q16_economic_spectrum  \
# 0                    2.0                  4.0                    4.0
# 1                    2.0                  4.0                    2.0
# 2                    NaN                  NaN                    NaN
# 3                    NaN                  NaN                    NaN
# 4                    2.0                  4.0                    NaN
#
#    Q16_social_spectrum
# 0                  2.0
# 1                  4.0
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 68 columns]

# %%
info_dict
# Out:
# {'cluster_input_cols': ['PC_0',
#   'PC_1',
#   'PC_2',
#   'PC_3',
#   'PC_4',
#   'PC_5',
#   'PC_6',
#   'PC_7',
#   'PC_8',
#   'PC_9',
#   'PC_10'],
#  'data_path': 'data/preprocessing/dim_reduction/220324_pca_data.csv',
#  'pca_data': True,
#  'scaler_type': 'MinMaxScaler()'}

# %%
answers_sampled = pd.DataFrame(answers).sample(10000).to_numpy()

# %% [markdown]
# # GM clustering

# %% [markdown]
# ## Elbow approach to determine ideal amount of clusters

# %%
# Set up a range of cluster numbers to try
n_range = range(2,15)

# Create empty lists to store the BIC and AIC values
bic_score = []
aic_score = []

# Loop through the range and fit a model
for n in tqdm(n_range):
    gm = GaussianMixture(n_components=n, 
                         random_state=123, 
                         n_init=6)
    gm.fit(answers_sampled)
    cluster_labels = gm.predict(answers_sampled)
    # Append the BIC and AIC to the respective lists
    bic_score.append(gm.bic(answers_sampled))
    aic_score.append(gm.aic(answers_sampled))
# Out:
# 100%|██████████| 13/13 [03:07<00:00, 14.43s/it]

# %%
# Plot the BIC and AIC values together
fig, ax = plt.subplots(figsize=(12,8),nrows=1)
ax.plot(n_range, bic_score, '-o', color='orange')
ax.plot(n_range, aic_score, '-o', color='green')
ax.set(xlabel='Number of Clusters', ylabel='Score')
ax.set_xticks(n_range)
ax.set_title('BIC and AIC Scores Per Number Of Clusters')
# Out:
# Text(0.5, 1.0, 'BIC and AIC Scores Per Number Of Clusters')

# %% [markdown]
# ## Probabilistic Approach to determine number of clusters

# %%
from scipy.stats import norm
mean = 2
std = 3
prior_dist = norm(loc=mean, scale=std)

# %%
x = np.arange(13)
plt.plot(x, prior_dist.pdf(x),
       'r-', lw=5, alpha=0.6, label='norm pdf')
plt.show()
plt.plot(x, prior_dist.logpdf(x),
       'r-', lw=5, alpha=0.6, label='norm pdf')
plt.show()

# %%
# Set up a range of cluster numbers to try
n_range = range(2,15)
list_log_prob_data_given_model = []
list_log_prob_model = []
list_score = []

# Loop through the range and fit a model
for n in tqdm(n_range):
    # init & fit gmm
    gm = GaussianMixture(n_components=n, 
                         random_state=123, 
                         n_init=6)
    gm.fit(answers_sampled)
    
    # Calculate Log Probabilities
    log_prob_data_given_model = gm.score(answers_sampled) # Computes the per-sample average log-likelihood of the given data X
    log_prob_model = prior_dist.logpdf(n)
    score = log_prob_data_given_model + log_prob_model

    # Append values to list
    list_log_prob_data_given_model.append(log_prob_data_given_model)
    list_log_prob_model.append(log_prob_model)
    list_score.append(score)
# Out:
# 100%|██████████| 13/13 [02:50<00:00, 13.08s/it]

# %%
# Plot the BIC and AIC values together
fig, ax = plt.subplots(figsize=(12,8),nrows=1)
ax.plot(n_range, list_log_prob_data_given_model, '-o', color='orange', label='log prob data given model')
ax.plot(n_range, list_log_prob_model, '-o', color='green', label='log prob model')
ax.plot(n_range, list_score, '-o', color='blue', label='score')
ax.set(xlabel='Number of Clusters', ylabel='Score')
ax.set_xticks(n_range)
ax.legend()
ax.set_title('Probabilistic Evaluation')
# Out:
# Text(0.5, 1.0, 'Probabilistic Evaluation')

# %%
list_score
# Out:
# [-16.784519679234453,
#  -16.594883905482277,
#  -16.35523701187057,
#  -16.36339274627025,
#  -16.526369048086856,
#  -16.89298732824197,
#  -17.43140414334096,
#  -17.970264081213305,
#  -18.771915174605724,
#  -19.440062122292883,
#  -20.425419589376293,
#  -21.464492649277386,
#  -22.7317552189012]

# %%
n_clusters = n_range[np.argmax(list_score)]
n_clusters
# Out:
# 4

# %% [markdown]
# ## GM fit

# %%
n_clusters = 3
gm = GaussianMixture(n_components=n_clusters, 
                         random_state=123, 
                         n_init=6)
gm.fit(answers)
# Out:
# GaussianMixture(n_components=3, n_init=6, random_state=123)

# %%
df['group'] = gm.predict(answers)
df['group_prob'] = pd.DataFrame(gm.predict_proba(answers)).max(axis=1)
df.head()
# Out:
#        PC_0      PC_1      PC_2      PC_3      PC_4      PC_5      PC_6  \
# 0 -0.699479 -0.770944 -0.628573 -1.347859 -0.362089  1.003139 -0.011299
# 1 -1.042685  0.134720 -0.322130  1.520663 -1.429726  0.553071 -1.170322
# 2 -1.090649  0.528105  0.389838  1.141938  1.297194 -1.068319 -0.257879
# 3  0.103301 -1.561799  1.319970 -0.147182  2.345984  1.095251  0.345532
# 4  1.908322 -1.268602  4.034475 -0.402159  0.807604 -0.425695 -1.042586
#
#        PC_7      PC_8      PC_9  ...  Q14_ocupation_employee_public  \
# 0  0.133365  1.154861 -0.111807  ...                              1
# 1 -1.384575 -1.049615  0.161217  ...                              1
# 2 -0.794440 -0.420931  1.823400  ...                              1
# 3 -2.371791 -1.517903 -0.073005  ...                              0
# 4 -1.173911  0.550262  1.374492  ...                              0
#
#    Q14_ocupation_self_employed Q14_ocupation_student  Q14_ocupation_other  \
# 0                            0                     0                    0
# 1                            0                     0                    0
# 2                            0                     0                    0
# 3                            0                     0                    0
# 4                            0                     0                    1
#
#   Q15_economic_spectrum  Q15_social_spectrum  Q16_economic_spectrum  \
# 0                   2.0                  4.0                    4.0
# 1                   2.0                  4.0                    2.0
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   2.0                  4.0                    NaN
#
#    Q16_social_spectrum  group  group_prob
# 0                  2.0      1    0.962010
# 1                  4.0      1    0.956483
# 2                  NaN      2    0.975808
# 3                  NaN      0    1.000000
# 4                  NaN      0    1.000000
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Save for general clustering evaluation

# %%
df.to_csv('data/clustering/220323_gmm_clustered_pca_3cluster.csv', index=False)

# %% [markdown]
# # Specific Clustering Method Analysis

# %%
gm.weights_
# Out:
# array([0.28843901, 0.44322344, 0.26833755])

# %%
df['group'].value_counts(dropna=False)
# Out:
# 1    54541
# 0    36294
# 2    31994
# Name: group, dtype: int64

# %% [markdown]
# ## Group Probability

# %%
df_sample = df.sample(1000)
sns.histplot(data=df_sample, multiple='stack', x="group_prob", hue="group", log_scale=(False, False), binwidth=0.1, palette='Set2')
plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(data=df_sample, ax=ax, multiple='stack', x="group_prob", hue="group", log_scale=(False, False), binwidth=0.1, palette='Set2')
ax.set_xlim(0.35, 1)
ax.set_ylim(0,80)
plt.show()

# %%
prob_list = []
for i in np.arange(0, 0.2, 0.01):
  prob = df['group_prob'].quantile(i)
  prob_list.append(prob)

plt.plot(prob_list)
plt.show()
