# %%
import pandas as pd
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import datetime, timedelta
import os
from clustering.utils import *

# %%
#%cd ..

# %%
df, cluster_input_cols, answers_train, answers, labels, _ = get_cluster_data(n_cluster=2, method='kmeans', cov_type='full', cluster_input_data='fa_data', start_train='2020-09-15', end_train='2020-12-01', start='2020-07-21')

# %%
df1 = df[['date', 'group']]

# %%
percentages_split = df1.groupby('date').mean()

# %%
df, cluster_input_cols, answers_train, answers, labels, _ = get_cluster_data(n_cluster=2, method='kmeans', cov_type='full', cluster_input_data='fa_data', start_train='2020-09-15', end_train='2021-02-01', start='2020-07-21')
df1 = df[['date', 'group']]
percentages = df1.groupby('date').mean()

# %%
plt.plot(percentages_split.to_numpy())
plt.plot(percentages.to_numpy())
plt.plot(gp['1'])
plt.show()

# %%
gp = pd.read_csv('data/modeling/group_percentage_non_careful.csv')

# %%
percentages_split.to_csv('data/modeling/group_percentage_non_careful_new.csv', index=False)

# %%
percentages_split
# Out:
#                group
# date
# 2020-07-21  0.377778
# 2020-07-22  0.456747
# 2020-07-23  0.429787
# 2020-07-24  0.438247
# 2020-07-25  0.364742
# ...              ...
# 2021-01-27  0.279835
# 2021-01-28  0.324895
# 2021-01-29  0.265896
# 2021-01-30  0.367347
# 2021-01-31  0.321918
#
# [195 rows x 1 columns]
